# %%
import numpy as np
from numpy.random import default_rng

# %%
rng = default_rng(932) # Generate random number generator

# %%
import math
random_normal_men_heights = rng.normal(174, 5.8, size=1000) # Generate random avg height
random_normal_men_weights = rng.normal(77,11, size =1000) # Generate random avg weight

heights = random_normal_men_heights
weights = random_normal_men_weights

heights.sort()
weights.sort()

print(heights)
# Out:
# [154.91886071 155.0068634  155.0908334  157.3800277  157.61298961
#  158.89072156 159.11069938 159.96341991 160.05775447 160.1801125
#  160.36553132 160.61414625 161.28008843 161.31640215 161.34504143
#  161.58067575 161.61893488 161.76906595 162.5558283  162.61601196
#  162.83283572 162.95509518 162.97603476 163.35670466 163.38506527
#  163.57045646 163.5798374  163.60610293 163.66755332 163.82616226
#  163.85225354 163.90399741 163.92123827 164.04523366 164.08900019
#  164.08904691 164.13139635 164.35309619 164.38297976 164.3831373
#  164.49204657 164.54711016 164.55555615 164.69599236 164.84161236
#  164.86423898 164.8835969  164.92729579 165.05786832 165.074297
#  165.26528346 165.35276057 165.38241408 165.42430089 165.4857123
#  165.49345412 165.49986647 165.54262126 165.61305518 165.63993563
#  165.88607107 165.89472973 165.90514789 166.00080533 166.043232
#  166.05539505 166.11985623 166.12469055 166.14546644 166.22275156
# ...

# %%
def my_percentile():
    #  my_h should be in cm.
    #  my_w  should be in kg.
    my_h = float(input("Input your height in cm : "))
    my_w = float(input("Input your weight in kg : "))
    while True:
        if (isinstance(my_h, float) == False or my_h < 0): 
            my_h = float(input("Need valid height in centimeters! : "))
        if (isinstance(my_w, float)== False or my_w < 0):
            my_w = float(input("Need Valid weight in kilograms! : "))

        else:
            break



    percentile_msg = "Quick Note, an i th percentile means that out of 100 random people, you are the i th person in comparison to other individuals"
    print(percentile_msg)
    print("\n")

    my_h_percentile = 0
    my_w_percentile = 0

    height_acc = 0
    weight_acc = 0

    for i in range(len(heights)):
        if heights[i] >= my_h:
            my_h_percentile = math.ceil(((len(heights) - height_acc) / len(heights)) * 100)
            if my_h_percentile == 1:
                print("Your height " + str(my_h) + "cm stands at the " + str(my_h_percentile) + "st percentile")
                break
            elif my_h_percentile == 2:
                print("Your height " + str(my_h) + "cm stands at the " + str(my_h_percentile) + "nd percentile")
                break
            elif my_h_percentile == 3:
                print("Your height " + str(my_h) + "cm stands at the " + str(my_h_percentile) + "rd percentile")
                break
            else:
                print("Your height " + str(my_h) + "cm stands at the " + str(my_h_percentile) + "th percentile")
                break
            
        else:
            height_acc += 1  
    
    for j in range(len(weights)):
        if weights[j] >= my_w:
            my_w_percentile = math.ceil(((len(weights) - weight_acc) / len(weights)) * 100)

            if my_w_percentile == 1:
                print("and your weight " + str(my_w) +"kg at the " + str(my_w_percentile) + "st percentile.")
                break
            elif my_w_percentile == 2:
                print("and your weight " + str(my_w) +"kg at the " + str(my_w_percentile) + "nd percentile.")
                break
            elif my_w_percentile == 3:
                print("and your weight " + str(my_w) +"kg at the " + str(my_w_percentile) + "rd percentile.")
                break
            else:
                
                print("and your weight " + str(my_w) +"kg at the " + str(my_w_percentile) + "th percentile")
                print("out of 1000 random sample of an adult men.")

                avg_msg = "Considering that the average is " + str(round(np.mean(heights), 2)) + "cm."

                if my_h_percentile <= 15:
                    print("You are considered tall")
                    print(avg_msg)
                elif (my_h_percentile > 15) and (my_h_percentile <= 40):
                    print("You are considered slightly taller than the average height")
                    print(avg_msg)
                elif (my_h_percentile > 40) and (my_h_percentile < 60):
                    print("You are considered to be an average height")
                    print(avg_msg)
                elif (my_h_percentile >= 60) and (my_h_percentile < 85):
                    print("You are considered slightly shorter than average")
                    print(avg_msg)
                else:
                    print("You are considered short")
                    print(avg_msg)
                break

        else:
            weight_acc += 1



# Edge cases that need to be dealt with: string input

# call my_percentile() to use the function.
# my_percentile()

# %%
import math

# 5 point summary data


def height_data_summary(list):
    print("The five number summary of this data is\n")
    print("Min : " + str(math.ceil((list[0])*100)/100) + "cm\n")
    print("First Quantile : " + str(math.ceil(np.median(list[:len(list)//2])*100)/100) + "cm\n")
    print("Median : " + str(math.ceil((np.median(list))*100)/100) + "cm\n")
    print("Third Quantile : " + str(math.ceil(((np.median(list[len(list)//2:]))*100)/100)) + "cm\n")
    print("Max :" + str(math.ceil((list[len(list)-1])*100)/100) + "cm\n")


def weight_data_summary(list):
    print("The five number summary of this data is\n")
    print("Min : " + str(math.ceil((list[0])*100)/100) + "kg\n")
    print("First Quantile : " + str(math.ceil(np.median(list[:len(list)//2])*100)/100) + "kg\n")
    print("Median : " + str(math.ceil((np.median(list))*100)/100) + "kg\n")
    print("Third Quantile : " + str(math.ceil(((np.median(list[len(list)//2:]))*100)/100)) + "kg\n")
    print("Max :" + str(math.ceil((list[len(list)-1])*100)/100) + "kg\n")


height_data_summary(heights)
print("-----------------------------------------------------")
weight_data_summary(weights)
# Out:
# The five number summary of this data is
#
# Min : 154.92cm
#
# First Quantile : 170.83cm
#
# Median : 174.47cm
#
# Third Quantile : 179cm
#
# Max :196.22cm
#
# -----------------------------------------------------
# The five number summary of this data is
#
# Min : 45.68kg
#
# First Quantile : 69.98kg
#
# Median : 77.42kg
#
# Third Quantile : 85kg
#
# Max :125.06kg

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Shows a graph of data

msg = "Below is a plotted graph of what we have initially randomly generated. This shape seems to converge very close to a normal distribution. Just a slight right skew."
print(msg)


# distribution of random 1000 heights
sns.histplot(heights, kde=True,binwidth=1, label='Sample Distribution')
plt.title("Normal Distribution of Data")
plt.xlabel("Heights in cm")
plt.ylabel("Number of Individuals for each group")


# Set x-axis with more detail
min_h = 150
max_h = 200
tick_freq = 5
plt.xticks(np.arange(min_h, max_h + 1, tick_freq))



# Now from here we implement to overlay a normal distribution of the same mean, std and size
mean_ideal = 174
std_dev_ideal = 5.8

# Generating points for the x-axis for the ideal curve
x_values = np.linspace(min_h, max_h, 1000)

# Calculating the probability density function for the ideal curve
ideal_pdf = (1 / (std_dev_ideal * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x_values - mean_ideal) / std_dev_ideal) ** 2)

# Scaling the PDF to match the histogram scale
# Assuming a bin width for the histogram
bin_width = 1
scaled_pdf = ideal_pdf * 1000 * bin_width

# Plotting the scaled ideal normal distribution curve
plt.plot(x_values, scaled_pdf, color='red', label='Ideal Normal Distribution')

# Adding the legend
plt.legend()

plt.show()
# Out:
# Below is a plotted graph of what we have initially randomly generated. This shape seems to converge very close to a normal distribution. Just a slight right skew.

# %%
def BMI_Calculator():
    h = float(input("Enter your height in cm : "))
    w = float(input("Enter your weight in kg : "))
    bmi = math.ceil((w/(h/100)**2) *100) /100
    print("BMI Levels: ")
    print("BMI value > 30.0 = Obesity")
    print("BMI value 25 ~ 29.9 = Overweight ")
    print("BMI value 18.5 ~ 24.9 = Healthy Weight!")
    print("BMI value < 18.5 = Underweight")
    print("------------------Result------------------")


    if bmi > 30:
        print("You, " + str(h) +"cm, " + str(w) + "kg have a BMI level of " + str(bmi))

        print("You are obese.")
    elif (bmi >= 25) and (bmi < 30):
        print("You, " + str(h) +"cm, " + str(w) + "kg have a BMI level of " + str(bmi))

        print("You are overweight.")
    elif (bmi >= 18.5 and bmi < 25):
        print("You, " + str(h) +"cm, " + str(w) + "kg have a BMI level of " + str(bmi))

        print("You are in a normal range")
    else:
        print("You, " + str(h) +"cm, " + str(w) + "kg have a BMI level of " + str(bmi))
        
        print("You are underweight.")


# Call this when you want to use it
# BMI_Calculator()
